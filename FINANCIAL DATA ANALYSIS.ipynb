# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %% [markdown]
# # BALANCE SHEET FOR NIO

# %%
#nbs representing nio balance sheet
nbs = pd.read_csv("NioBS.csv")
nbs
# Out:
#                             Year           TTM    2021-12-31    2020-12-31  \
# 0             Cash & Equivalents  1.983144e+10  1.832813e+10  3.850355e+10
# 1         Short-Term Investments  3.350743e+10  3.705755e+10  3.950747e+09
# 2        Cash & Cash Equivalents  5.333888e+10  5.538568e+10  4.245430e+10
# 3                    Cash Growth           NaN  3.045954e-01  3.918977e+01
# 4                    Receivables  5.202110e+09  4.349139e+09  1.293825e+09
# 5                      Inventory  2.676502e+09  2.056352e+09  1.081553e+09
# 6           Other Current Assets  3.090967e+09  1.850143e+09  1.377141e+09
# 7           Total Current Assets  6.430846e+10  6.364132e+10  4.620682e+10
# 8    Property, Plant & Equipment  1.190975e+10  1.038789e+10  6.346522e+09
# 9          Long-Term Investments  4.098705e+09  3.105820e+09  3.416680e+08
# 10      Goodwill and Intangibles  1.979100e+08  1.991210e+08  2.045810e+08
# ...

# %%
#To check that there are no missing values
nbs.isnull().sum()
# Out:
# Year          0
# TTM           5
# 2021-12-31    0
# 2020-12-31    1
# 2019-12-31    1
# 2018-12-31    0
# 2017-12-31    0
# 2016-12-31    3
# dtype: int64

# %%
nbs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 34 entries, 0 to 33
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        34 non-null     object
#  1   TTM         29 non-null     float64
#  2   2021-12-31  34 non-null     float64
#  3   2020-12-31  33 non-null     float64
#  4   2019-12-31  33 non-null     float64
#  5   2018-12-31  34 non-null     float64
#  6   2017-12-31  34 non-null     float64
#  7   2016-12-31  31 non-null     float64
# dtypes: float64(7), object(1)
# memory usage: 2.2+ KB

# %%
#Creating a copy of the file
nbscopy = nbs.copy()
nbscopy
# Out:
#                             Year           TTM    2021-12-31    2020-12-31  \
# 0             Cash & Equivalents  1.983144e+10  1.832813e+10  3.850355e+10
# 1         Short-Term Investments  3.350743e+10  3.705755e+10  3.950747e+09
# 2        Cash & Cash Equivalents  5.333888e+10  5.538568e+10  4.245430e+10
# 3                    Cash Growth           NaN  3.045954e-01  3.918977e+01
# 4                    Receivables  5.202110e+09  4.349139e+09  1.293825e+09
# 5                      Inventory  2.676502e+09  2.056352e+09  1.081553e+09
# 6           Other Current Assets  3.090967e+09  1.850143e+09  1.377141e+09
# 7           Total Current Assets  6.430846e+10  6.364132e+10  4.620682e+10
# 8    Property, Plant & Equipment  1.190975e+10  1.038789e+10  6.346522e+09
# 9          Long-Term Investments  4.098705e+09  3.105820e+09  3.416680e+08
# 10      Goodwill and Intangibles  1.979100e+08  1.991210e+08  2.045810e+08
# ...

# %%
#Dropping the columns not needed
nbscopy.drop(["TTM", "2016-12-31"], axis=1, inplace = True)
nbscopy
# Out:
#                             Year    2021-12-31    2020-12-31    2019-12-31  \
# 0             Cash & Equivalents  1.832813e+10  3.850355e+10  9.453460e+08
# 1         Short-Term Investments  3.705755e+10  3.950747e+09  1.110000e+08
# 2        Cash & Cash Equivalents  5.538568e+10  4.245430e+10  1.056346e+09
# 3                    Cash Growth  3.045954e-01  3.918977e+01 -8.734242e-01
# 4                    Receivables  4.349139e+09  1.293825e+09  1.402876e+09
# 5                      Inventory  2.056352e+09  1.081553e+09  8.895280e+08
# 6           Other Current Assets  1.850143e+09  1.377141e+09  1.579258e+09
# 7           Total Current Assets  6.364132e+10  4.620682e+10  4.928008e+09
# 8    Property, Plant & Equipment  1.038789e+10  6.346522e+09  7.530736e+09
# 9          Long-Term Investments  3.105820e+09  3.416680e+08  1.598480e+08
# 10      Goodwill and Intangibles  1.991210e+08  2.045810e+08  2.103370e+08
# ...

# %%
#Reconfirming no missing values
nbscopy.isnull().sum()
# Out:
# Year          0
# 2021-12-31    0
# 2020-12-31    1
# 2019-12-31    1
# 2018-12-31    0
# 2017-12-31    0
# dtype: int64

# %%
nbscopy.isna()
# Out:
#      Year  2021-12-31  2020-12-31  2019-12-31  2018-12-31  2017-12-31
# 0   False       False       False       False       False       False
# 1   False       False       False       False       False       False
# 2   False       False       False       False       False       False
# 3   False       False       False       False       False       False
# 4   False       False       False       False       False       False
# 5   False       False       False       False       False       False
# 6   False       False       False       False       False       False
# 7   False       False       False       False       False       False
# 8   False       False       False       False       False       False
# 9   False       False       False       False       False       False
# 10  False       False       False       False       False       False
# 11  False       False       False       False       False       False
# ...

# %%
nbscopy.loc[30]
# Out:
# Year          Net Cash / Debt Growth
# 2021-12-31                   0.06855
# 2020-12-31                       NaN
# 2019-12-31                       NaN
# 2018-12-31                   -0.2537
# 2017-12-31                 11.588125
# Name: 30, dtype: object

# %%
#Replacig missing values
nbscopy.fillna(0, inplace= True)
nbscopy
# Out:
#                             Year    2021-12-31    2020-12-31    2019-12-31  \
# 0             Cash & Equivalents  1.832813e+10  3.850355e+10  9.453460e+08
# 1         Short-Term Investments  3.705755e+10  3.950747e+09  1.110000e+08
# 2        Cash & Cash Equivalents  5.538568e+10  4.245430e+10  1.056346e+09
# 3                    Cash Growth  3.045954e-01  3.918977e+01 -8.734242e-01
# 4                    Receivables  4.349139e+09  1.293825e+09  1.402876e+09
# 5                      Inventory  2.056352e+09  1.081553e+09  8.895280e+08
# 6           Other Current Assets  1.850143e+09  1.377141e+09  1.579258e+09
# 7           Total Current Assets  6.364132e+10  4.620682e+10  4.928008e+09
# 8    Property, Plant & Equipment  1.038789e+10  6.346522e+09  7.530736e+09
# 9          Long-Term Investments  3.105820e+09  3.416680e+08  1.598480e+08
# 10      Goodwill and Intangibles  1.991210e+08  2.045810e+08  2.103370e+08
# ...

# %%
nbscopy.isna().sum()
# Out:
# Year          0
# 2021-12-31    0
# 2020-12-31    0
# 2019-12-31    0
# 2018-12-31    0
# 2017-12-31    0
# dtype: int64

# %%
 nbscopy.astype({"2021-12-31":"int","2020-12-31":"int", "2019-12-31":"int" ,"2018-12-31":"int", "2017-12-31":"int"})
# Out:
#                             Year   2021-12-31   2020-12-31   2019-12-31  \
# 0             Cash & Equivalents  18328127000  38503551000    945346000
# 1         Short-Term Investments  37057554000   3950747000    111000000
# 2        Cash & Cash Equivalents  55385681000  42454298000   1056346000
# 3                    Cash Growth            0           39            0
# 4                    Receivables   4349139000   1293825000   1402876000
# 5                      Inventory   2056352000   1081553000    889528000
# 6           Other Current Assets   1850143000   1377141000   1579258000
# 7           Total Current Assets  63641315000  46206817000   4928008000
# 8    Property, Plant & Equipment  10387890000   6346522000   7530736000
# 9          Long-Term Investments   3105820000    341668000    159848000
# 10      Goodwill and Intangibles    199121000    204581000    210337000
# 11        Other Long-Term Assets   5549455000   1542341000   1753100000
# ...

# %%
#Selecting the data for analysis from the balance sheet
a = nbscopy.iloc[7:8]
b = nbscopy.iloc[16:17]
c = nbscopy.iloc[5:6]
d = nbscopy.iloc[27:28]

# %%
#merging the data
merged_balancesheet_data= pd.concat([a,b,c,d])
merged_balancesheet_data
# Out:
#                          Year    2021-12-31    2020-12-31    2019-12-31  \
# 7        Total Current Assets  6.364132e+10  4.620682e+10  4.928008e+09
# 16  Total Current Liabilities  2.919815e+10  1.397624e+10  9.498858e+09
# 5                   Inventory  2.056352e+09  1.081553e+09  8.895280e+08
# 27       Shareholders' Equity  3.470992e+10  2.716883e+10 -6.299686e+09
#
#       2018-12-31    2017-12-31
# 7   1.216963e+10  8.310005e+09
# 16  8.593386e+09  1.618514e+09
# 5   1.465239e+09  8.946400e+07
# 27  6.837041e+09 -1.160309e+10

# %% [markdown]
# # INCOME STATEMENT of NIO

# %%
#nis representing nio income statement
nis = pd.read_excel("NIS.xlsx")
nis
# Out:
#                             Year           TTM    2021-12-31    2020-12-31  \
# 0                        Revenue  3.806468e+10  3.613642e+10  1.625793e+10
# 1           Revenue Growth (YoY)           NaN  1.222690e+00  1.077720e+00
# 2                Cost of Revenue  3.135121e+10  2.931499e+10  1.438451e+10
# 3                   Gross Profit  6.713466e+09  6.821433e+09  1.873419e+09
# 4       Selling, General & Admin  7.695688e+09  6.878132e+09  3.932271e+09
# 5         Research & Development  5.666991e+09  4.591852e+09  2.487770e+09
# 6       Other Operating Expenses -2.601690e+08 -1.522480e+08  6.102300e+07
# 7             Operating Expenses  1.310251e+10  1.131774e+10  6.481064e+09
# 8               Operating Income -6.389044e+09 -4.496303e+09 -4.607645e+09
# 9      Interest Expense / Income  2.909930e+08  6.374100e+08  4.260150e+08
# 10        Other Expense / Income -1.455775e+09 -1.190248e+09  2.590920e+08
# ...

# %%
#To check that there are no missing values
nis.isnull().sum()
# Out:
# Year          0
# TTM           7
# 2021-12-31    0
# 2020-12-31    0
# 2019-12-31    0
# 2018-12-31    1
# 2017-12-31    7
# 2016-12-31    8
# dtype: int64

# %%
nis.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Year        32 non-null     object
#  1   TTM         25 non-null     float64
#  2   2021-12-31  32 non-null     float64
#  3   2020-12-31  32 non-null     float64
#  4   2019-12-31  32 non-null     float64
#  5   2018-12-31  31 non-null     float64
#  6   2017-12-31  25 non-null     float64
#  7   2016-12-31  24 non-null     float64
# dtypes: float64(7), object(1)
# memory usage: 2.1+ KB

# %%
#Creating a copy of the file
niscopy = nis.copy()
niscopy
# Out:
#                             Year           TTM    2021-12-31    2020-12-31  \
# 0                        Revenue  3.806468e+10  3.613642e+10  1.625793e+10
# 1           Revenue Growth (YoY)           NaN  1.222690e+00  1.077720e+00
# 2                Cost of Revenue  3.135121e+10  2.931499e+10  1.438451e+10
# 3                   Gross Profit  6.713466e+09  6.821433e+09  1.873419e+09
# 4       Selling, General & Admin  7.695688e+09  6.878132e+09  3.932271e+09
# 5         Research & Development  5.666991e+09  4.591852e+09  2.487770e+09
# 6       Other Operating Expenses -2.601690e+08 -1.522480e+08  6.102300e+07
# 7             Operating Expenses  1.310251e+10  1.131774e+10  6.481064e+09
# 8               Operating Income -6.389044e+09 -4.496303e+09 -4.607645e+09
# 9      Interest Expense / Income  2.909930e+08  6.374100e+08  4.260150e+08
# 10        Other Expense / Income -1.455775e+09 -1.190248e+09  2.590920e+08
# ...

# %%
#Dropping the columns not needed
nistatement = niscopy.drop(['TTM', '2016-12-31'], axis=1)
nistatement
# Out:
#                             Year    2021-12-31    2020-12-31    2019-12-31  \
# 0                        Revenue  3.613642e+10  1.625793e+10  7.824904e+09
# 1           Revenue Growth (YoY)  1.222690e+00  1.077720e+00  5.804100e-01
# 2                Cost of Revenue  2.931499e+10  1.438451e+10  9.023726e+09
# 3                   Gross Profit  6.821433e+09  1.873419e+09 -1.198822e+09
# 4       Selling, General & Admin  6.878132e+09  3.932271e+09  5.451787e+09
# 5         Research & Development  4.591852e+09  2.487770e+09  4.428580e+09
# 6       Other Operating Expenses -1.522480e+08  6.102300e+07  0.000000e+00
# 7             Operating Expenses  1.131774e+10  6.481064e+09  9.880367e+09
# 8               Operating Income -4.496303e+09 -4.607645e+09 -1.107919e+10
# 9      Interest Expense / Income  6.374100e+08  4.260150e+08  3.705360e+08
# 10        Other Expense / Income -1.190248e+09  2.590920e+08 -1.711020e+08
# ...

# %%
nistatement.isnull().sum()
# Out:
# Year          0
# 2021-12-31    0
# 2020-12-31    0
# 2019-12-31    0
# 2018-12-31    1
# 2017-12-31    7
# dtype: int64

# %%
nistatement.isna()
# Out:
#      Year  2021-12-31  2020-12-31  2019-12-31  2018-12-31  2017-12-31
# 0   False       False       False       False       False       False
# 1   False       False       False       False        True        True
# 2   False       False       False       False       False       False
# 3   False       False       False       False       False       False
# 4   False       False       False       False       False       False
# 5   False       False       False       False       False       False
# 6   False       False       False       False       False       False
# 7   False       False       False       False       False       False
# 8   False       False       False       False       False       False
# 9   False       False       False       False       False       False
# 10  False       False       False       False       False       False
# 11  False       False       False       False       False       False
# ...

# %%
#Replacing missing values
nistatement.fillna(0, inplace= True)

# %%
nistatement.isna().sum()
# Out:
# Year          0
# 2021-12-31    0
# 2020-12-31    0
# 2019-12-31    0
# 2018-12-31    0
# 2017-12-31    0
# dtype: int64

# %%
#Selecting the data for analysis from the income statement
e = nistatement.iloc[0:1]
f = nistatement.iloc[2:3]
g = nistatement.iloc[13:14]
h = nistatement.iloc[19:20]
i= nistatement.iloc[22:25]

# %%
#merging the data
merged_incomestatement_data= pd.concat([e,f,g,h,i])
merged_incomestatement_data
# Out:
#                 Year    2021-12-31    2020-12-31    2019-12-31    2018-12-31  \
# 0            Revenue  3.613642e+10  1.625793e+10  7.824904e+09  4.951171e+09
# 2    Cost of Revenue  2.931499e+10  1.438451e+10  9.023726e+09  5.207047e+09
# 13        Net Income -3.985730e+09 -5.299120e+09 -1.128651e+10 -9.597274e+09
# 19       EPS (Basic) -6.720000e+00 -4.740000e+00 -1.108000e+01 -7.023000e+01
# 22      Gross Margin  1.887700e-01  1.152300e-01 -1.532100e-01 -5.168000e-02
# 23  Operating Margin -1.244300e-01 -2.834100e-01 -1.415890e+00 -1.938050e+00
# 24     Profit Margin -2.925700e-01 -3.451100e-01 -1.458560e+00 -4.711580e+00
#
#       2017-12-31
# 0   0.000000e+00
# 2   0.000000e+00
# 13 -4.984734e+09
# 19 -3.468400e+02
# 22  0.000000e+00
# 23  0.000000e+00
# 24  0.000000e+00

# %% [markdown]
# # WHOLE DATA FOR ANALSIS

# %%
#Merging the selected data from the balance sheet and the income statement
wholedata = pd.concat([merged_balancesheet_data,merged_incomestatement_data])
wholedata
# Out:
#                          Year    2021-12-31    2020-12-31    2019-12-31  \
# 7        Total Current Assets  6.364132e+10  4.620682e+10  4.928008e+09
# 16  Total Current Liabilities  2.919815e+10  1.397624e+10  9.498858e+09
# 5                   Inventory  2.056352e+09  1.081553e+09  8.895280e+08
# 27       Shareholders' Equity  3.470992e+10  2.716883e+10 -6.299686e+09
# 0                     Revenue  3.613642e+10  1.625793e+10  7.824904e+09
# 2             Cost of Revenue  2.931499e+10  1.438451e+10  9.023726e+09
# 13                 Net Income -3.985730e+09 -5.299120e+09 -1.128651e+10
# 19                EPS (Basic) -6.720000e+00 -4.740000e+00 -1.108000e+01
# 22               Gross Margin  1.887700e-01  1.152300e-01 -1.532100e-01
# 23           Operating Margin -1.244300e-01 -2.834100e-01 -1.415890e+00
# 24              Profit Margin -2.925700e-01 -3.451100e-01 -1.458560e+00
#
#       2018-12-31    2017-12-31
# 7   1.216963e+10  8.310005e+09
# 16  8.593386e+09  1.618514e+09
# ...

# %%
# changing a column name from the data
change_column = np.array(wholedata.columns)
change_column[0] = 'S/N'
change_column
# Out:
# array(['S/N', '2021-12-31', '2020-12-31', '2019-12-31', '2018-12-31',
#        '2017-12-31'], dtype=object)

# %%
# now lets try and receate the datafame with the new column
data = pd.DataFrame(wholedata.values, columns = change_column)
data.head()
# Out:
#                          S/N     2021-12-31     2020-12-31    2019-12-31  \
# 0       Total Current Assets  63641315000.0  46206817000.0  4928008000.0
# 1  Total Current Liabilities  29198152000.0  13976240000.0  9498858000.0
# 2                  Inventory   2056352000.0   1081553000.0   889528000.0
# 3       Shareholders' Equity  34709924000.0  27168831000.0 -6299686000.0
# 4                    Revenue  36136423000.0  16257933000.0  7824904000.0
#
#       2018-12-31     2017-12-31
# 0  12169632000.0   8310005000.0
# 1   8593386000.0   1618514000.0
# 2   1465239000.0     89464000.0
# 3   6837041000.0 -11603089000.0
# 4   4951171000.0            0.0

# %%
#Transposing the data columns and rows
data_transposed = data.T 
data_transposed
# Out:
#                               0                          1             2   \
# S/N         Total Current Assets  Total Current Liabilities     Inventory
# 2021-12-31         63641315000.0              29198152000.0  2056352000.0
# 2020-12-31         46206817000.0              13976240000.0  1081553000.0
# 2019-12-31          4928008000.0               9498858000.0   889528000.0
# 2018-12-31         12169632000.0               8593386000.0  1465239000.0
# 2017-12-31          8310005000.0               1618514000.0    89464000.0
#
#                               3              4                5   \
# S/N         Shareholders' Equity        Revenue  Cost of Revenue
# 2021-12-31         34709924000.0  36136423000.0    29314990000.0
# 2020-12-31         27168831000.0  16257933000.0    14384514000.0
# 2019-12-31         -6299686000.0   7824904000.0     9023726000.0
# 2018-12-31          6837041000.0   4951171000.0     5207047000.0
# ...

# %%
data_transposed.columns = data_transposed.iloc[0]
data_transposed
# Out:
# S/N         Total Current Assets  Total Current Liabilities     Inventory  \
# S/N         Total Current Assets  Total Current Liabilities     Inventory
# 2021-12-31         63641315000.0              29198152000.0  2056352000.0
# 2020-12-31         46206817000.0              13976240000.0  1081553000.0
# 2019-12-31          4928008000.0               9498858000.0   889528000.0
# 2018-12-31         12169632000.0               8593386000.0  1465239000.0
# 2017-12-31          8310005000.0               1618514000.0    89464000.0
#
# S/N         Shareholders' Equity        Revenue  Cost of Revenue  \
# S/N         Shareholders' Equity        Revenue  Cost of Revenue
# 2021-12-31         34709924000.0  36136423000.0    29314990000.0
# 2020-12-31         27168831000.0  16257933000.0    14384514000.0
# 2019-12-31         -6299686000.0   7824904000.0     9023726000.0
# 2018-12-31          6837041000.0   4951171000.0     5207047000.0
# ...

# %%
cleaned_fiancial_data = data_transposed.drop(labels='S/N',axis=0)
cleaned_fiancial_data
# Out:
# S/N        Total Current Assets Total Current Liabilities     Inventory  \
# 2021-12-31        63641315000.0             29198152000.0  2056352000.0
# 2020-12-31        46206817000.0             13976240000.0  1081553000.0
# 2019-12-31         4928008000.0              9498858000.0   889528000.0
# 2018-12-31        12169632000.0              8593386000.0  1465239000.0
# 2017-12-31         8310005000.0              1618514000.0    89464000.0
#
# S/N        Shareholders' Equity        Revenue Cost of Revenue     Net Income  \
# 2021-12-31        34709924000.0  36136423000.0   29314990000.0  -3985730000.0
# 2020-12-31        27168831000.0  16257933000.0   14384514000.0  -5299120000.0
# 2019-12-31        -6299686000.0   7824904000.0    9023726000.0 -11286511000.0
# 2018-12-31         6837041000.0   4951171000.0    5207047000.0  -9597274000.0
# 2017-12-31       -11603089000.0            0.0             0.0  -4984734000.0
#
# ...

# %%
cleaned_fiancial_data["Gross Margin"].plot()
plt.title("GROSS MARGIN OF NIO", fontsize =16, fontweight = "bold")
plt.ylabel("Gross Margin", fontsize = 13)
plt.xlabel("Year", fontsize = 13)
plt.show()


cleaned_fiancial_data["Operating Margin"].plot()
plt.title("OPERATING MARGIN OF NIO", fontsize =16, fontweight = "bold")
plt.ylabel("Operating Margin", fontsize = 13)
plt.xlabel("Year", fontsize = 13)
plt.show()

cleaned_fiancial_data["Profit Margin"].plot()
plt.title("PROFIT MARGIN OF NIO", fontsize =16, fontweight = "bold")
plt.ylabel("Profit Margin", fontsize = 13)
plt.xlabel("Year", fontsize = 13)
plt.show()

# %% [markdown]
# # PROFITABILITY RATIOS IN %

# %% [markdown]
# # Gross Margin

# %%
grossmargin_in_percentage= cleaned_fiancial_data["Gross Margin"]*100
grossmargin_in_percentage
# Out:
# 2021-12-31    18.877
# 2020-12-31    11.523
# 2019-12-31   -15.321
# 2018-12-31    -5.168
# 2017-12-31       0.0
# Name: Gross Margin, dtype: object

# %%
grossmargin_in_percentage.plot()
plt.title("GROSS MARGIN OF NIO", fontsize =16, fontweight = "bold")
plt.ylabel("Gross Margin(%)", fontsize = 13)
plt.xlabel("Year", fontsize = 13)
plt.show()

# %% [markdown]
# # OPERATING MARGIN

# %%
operatingmargin_in_percentage= cleaned_fiancial_data["Operating Margin"]*100
operatingmargin_in_percentage
# Out:
# 2021-12-31    -12.443
# 2020-12-31    -28.341
# 2019-12-31   -141.589
# 2018-12-31   -193.805
# 2017-12-31        0.0
# Name: Operating Margin, dtype: object

# %%
operatingmargin_in_percentage.plot()
plt.title("OPERATING MARGIN OF NIO", fontsize =16, fontweight = "bold")
plt.ylabel("Operating Margin(%)", fontsize = 13)
plt.xlabel("Year", fontsize = 13)
plt.show()

# %% [markdown]
# # PROFIT MARGIN

# %%
profitmargin_in_percentage= cleaned_fiancial_data["Profit Margin"]*100
profitmargin_in_percentage
profitmargin_in_percentage.plot()
plt.title("PROFIT MARGIN OF NIO", fontsize =16, fontweight = "bold")
plt.ylabel("Profit Margin(%)", fontsize = 13)
plt.xlabel("Year", fontsize = 13)
plt.show()

# %%
profitmargin_in_percentage.plot()
plt.title("GROSS MARGIN OF NIO", fontsize =16, fontweight = "bold")
plt.ylabel("Gross Margin(%)", fontsize = 13)
plt.xlabel("Year", fontsize = 13)
plt.show()

# %%
plt.plot(cleaned_fiancial_data["EPS (Basic)"], 'g', label='Line y')
plt.title("EARNINGS PER SHARE OF NIO", fontsize =16, fontweight = "bold")
plt.ylabel("EPS (Basic)", fontsize = 13)
plt.xlabel("Year", fontsize = 13)
plt.show()
plt.savefig('EPS(Basic).png')

# %% [markdown]
# # LIQUIDITY RATIOS

# %% [markdown]
# #Liquidity ratio is used to to determine a company’s ability to pay its short-term debt obligations.
# #Here we would look at the current ratio and quick ratio

# %%
current_asset = cleaned_fiancial_data['Total Current Assets']
current_asset
# Out:
# 2021-12-31    63641315000.0
# 2020-12-31    46206817000.0
# 2019-12-31     4928008000.0
# 2018-12-31    12169632000.0
# 2017-12-31     8310005000.0
# Name: Total Current Assets, dtype: object

# %%
current_liabilities = cleaned_fiancial_data['Total Current Liabilities']
current_liabilities
# Out:
# 2021-12-31    29198152000.0
# 2020-12-31    13976240000.0
# 2019-12-31     9498858000.0
# 2018-12-31     8593386000.0
# 2017-12-31     1618514000.0
# Name: Total Current Liabilities, dtype: object

# %%
inventory = cleaned_fiancial_data['Inventory']
inventory
# Out:
# 2021-12-31    2056352000.0
# 2020-12-31    1081553000.0
# 2019-12-31     889528000.0
# 2018-12-31    1465239000.0
# 2017-12-31      89464000.0
# Name: Inventory, dtype: object

# %%
current_ratio = current_asset/current_liabilities
current_ratio
# Out:
# 2021-12-31    2.179635
# 2020-12-31    3.306098
# 2019-12-31      0.5188
# 2018-12-31    1.416163
# 2017-12-31    5.134342
# dtype: object

# %%
quick_ratio = (current_asset - inventory)/current_liabilities
quick_ratio
# Out:
# 2021-12-31    2.109208
# 2020-12-31    3.228713
# 2019-12-31    0.425154
# 2018-12-31    1.245655
# 2017-12-31    5.079067
# dtype: object

# %% [markdown]
# # VISUALIZATION OF THE LIQUIDITY RATIOS

# %%
plt.plot(current_ratio, 'y', label='Line y')
plt.title("CURRENT RATIO OF NIO", fontsize =16, fontweight = "bold")
plt.ylabel("Current ratio", fontsize = 13)
plt.xlabel("Year", fontsize = 13)
plt.show()
plt.savefig('CURRENT RATIO OF NIO.png')

plt.plot(quick_ratio, 'r', label='Line y')
plt.title("Quick RATIO OF NIO", fontsize =16, fontweight = "bold")
plt.ylabel("Quick ratio", fontsize = 13)
plt.xlabel("Year", fontsize = 13)
plt.show()
plt.savefig('Quick RATIO OF NIO.png')

# %% [markdown]
# # PART B : STOCK PRICES VERSUS INFLATION

# %%
import pandas_datareader.data as web
import pandas as pd
import matplotlib.pyplot as plt

# %%
def cleandata(ticker):
    import pandas_datareader.data as web
    start='2020-01-01'
    end='2021-12-31'
    df = web.DataReader(ticker,'yahoo',start,end)
    df.dropna()
    df.rename(columns = {'Close' : ticker+'_Close'}, inplace = True)
    return df

# %%
df_Tesla = cleandata('TSLA')
df_HMC = cleandata('HMC')
df_TM = cleandata('TM')
df_NIO = cleandata('NIO')

# %%
df_Tesla.head()
# Out:
#                  High        Low       Open  TSLA_Close       Volume  \
# Date
# 2020-01-02  86.139999  84.342003  84.900002   86.052002   47660500.0
# 2020-01-03  90.800003  87.384003  88.099998   88.601997   88892500.0
# 2020-01-06  90.311996  88.000000  88.094002   90.307999   50665000.0
# 2020-01-07  94.325996  90.671997  92.279999   93.811996   89410500.0
# 2020-01-08  99.697998  93.646004  94.739998   98.428001  155721500.0
#
#             Adj Close
# Date
# 2020-01-02  86.052002
# 2020-01-03  88.601997
# 2020-01-06  90.307999
# 2020-01-07  93.811996
# 2020-01-08  98.428001

# %%
df_HMC.head()
# Out:
#                  High        Low       Open  HMC_Close  Volume  Adj Close
# Date
# 2020-01-02  28.650000  28.459999  28.600000  28.639999  262800  28.639999
# 2020-01-03  28.379999  28.080000  28.250000  28.129999  663600  28.129999
# 2020-01-06  28.059999  27.719999  27.719999  28.049999  463000  28.049999
# 2020-01-07  28.389999  28.180000  28.389999  28.209999  341800  28.209999
# 2020-01-08  28.219999  27.990000  27.990000  28.129999  264200  28.129999

# %%
df1= df_Tesla['TSLA_Close']
df2= df_HMC['HMC_Close']
df3= df_TM['TM_Close']
df4= df_NIO['NIO_Close']

# %%
combined = pd.concat([df1, df2,df3,df4], axis=1)
combined
# Out:
#              TSLA_Close  HMC_Close    TM_Close  NIO_Close
# Date
# 2020-01-02    86.052002  28.639999  142.240005   3.720000
# 2020-01-03    88.601997  28.129999  140.750000   3.830000
# 2020-01-06    90.307999  28.049999  140.770004   3.680000
# 2020-01-07    93.811996  28.209999  141.509995   3.240000
# 2020-01-08    98.428001  28.129999  141.160004   3.390000
# ...                 ...        ...         ...        ...
# 2021-12-27  1093.939941  28.209999  185.899994  29.959999
# 2021-12-28  1088.469971  28.200001  184.750000  29.629999
# 2021-12-29  1086.189941  28.180000  183.679993  28.250000
# 2021-12-30  1070.339966  28.240000  184.080002  32.419998
# 2021-12-31  1056.780029  28.450001  185.300003  31.680000
#
# [505 rows x 4 columns]

# %%
combined.plot(title='Stock prices', xlabel= "Date", ylabel="Stock prices($)")
# Out:
# <AxesSubplot:title={'center':'Stock prices'}, xlabel='Date', ylabel='Stock prices($)'>

# %%
def cleandata2(ticker):
    import pandas_datareader.data as web
    start='2020-01-01'
    end='2021-12-31'
    df = web.DataReader(ticker,'fred',start,end)
    return df

# %%
inflation = cleandata2('T5YIE')
inflation
# Out:
#             T5YIE
# DATE
# 2020-01-01    NaN
# 2020-01-02   1.72
# 2020-01-03   1.69
# 2020-01-06   1.69
# 2020-01-07   1.67
# ...           ...
# 2021-12-27   2.75
# 2021-12-28   2.78
# 2021-12-29   2.83
# 2021-12-30   2.86
# 2021-12-31   2.87
#
# [523 rows x 1 columns]

# %%
 inflation.dropna()
# Out:
#             T5YIE
# DATE
# 2020-01-02   1.72
# 2020-01-03   1.69
# 2020-01-06   1.69
# 2020-01-07   1.67
# 2020-01-08   1.68
# ...           ...
# 2021-12-27   2.75
# 2021-12-28   2.78
# 2021-12-29   2.83
# 2021-12-30   2.86
# 2021-12-31   2.87
#
# [502 rows x 1 columns]

# %%
inflation['T5YIE'].plot(title= 'inflation', xlabel= "Date", ylabel="Inflation(%)") 
combined.plot(title='Stock prices', xlabel= "Date", ylabel="Stock prices($)")
# Out:
# <AxesSubplot:title={'center':'Stock prices'}, xlabel='Date', ylabel='Stock prices($)'>
